# %% [markdown]
# # Feature selection with variance

# %%
import pandas as pd
import numpy as np
import statistics
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import f_oneway, rankdata
from sklearn.feature_selection import RFE
from sklearn.feature_selection import mutual_info_classif
from sklearn.linear_model import LinearRegression
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ## read in data

# %%
# read in file
df = pd.read_csv("Brain_GSE50161.csv")

# %%
df
# Out:
#      samples                   type  1007_s_at   1053_at     117_at    121_at  \
# 0        834             ependymoma  12.498150  7.604868   6.880934  9.027128
# 1        835             ependymoma  13.067436  7.998090   7.209076  9.723322
# 2        836             ependymoma  13.068179  8.573674   8.647684  9.613002
# 3        837             ependymoma  12.456040  9.098977   6.628784  8.517677
# 4        838             ependymoma  12.699958  8.800721  11.556188  9.166309
# ..       ...                    ...        ...       ...        ...       ...
# 125      959  pilocytic_astrocytoma  12.658228  8.843270   7.672655  9.125912
# 126      960  pilocytic_astrocytoma  12.812823  8.510550   8.729699  9.104402
# 127      961  pilocytic_astrocytoma  12.706991  8.795721   7.772359  8.327273
# 128      962  pilocytic_astrocytoma  12.684593  8.293938   7.228186  8.494428
# 129      963  pilocytic_astrocytoma  12.397722  8.843524   8.825100  8.551541
#
# ...

# %%
#Count the number of samples of five subtypes.
def count_plot(label, title):
    ax = sns.countplot(x=label)
    for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
    plt.title(title)
    plt.show()

# %%
subtype_counts = count_plot(df["type"], "Five different subtype data counts")
subtype_counts

# %%
# first column is the samples
# second column is the types for brain cancers.
print(df['type'].value_counts())
# replace type to numbers
df['type'] = df['type'].replace(['ependymoma', 'glioblastoma','medulloblastoma', 'pilocytic_astrocytoma','normal'],[0,1,2,3,4])
# Out:
# ependymoma               46
# glioblastoma             34
# medulloblastoma          22
# pilocytic_astrocytoma    15
# normal                   13
# Name: type, dtype: int64

# %% [markdown]
# ## Filter Methods

# %%
# Use ANOVA to filter genes based on p-value

stat_ANOVA = []

# loop through each gene 
# to get gene expression values for a certain gene for each subtype
# to get all gene expression values for each subtype (whole loop)
for g in range(2, df.shape[1]):
    
    # subset type 0 (ependymoma) for gene g
    # .iloc[:,g] means all rows and column g
    type0 = np.array(df[df.type == 0].iloc[:,g])
    
    # subset type 1 (glioblastoma) for gene g
    type1 = np.array(df[df.type == 1].iloc[:,g])
    
    # subset type 2 (medulloblastoma) for gene g
    type2 = np.array(df[df.type == 2].iloc[:,g])
    
    # subset type 3 (pilocytic_astrocytoma) for gene g
    type3 = np.array(df[df.type == 3].iloc[:,g])
    
    # subset type 4 (normal) for gene g
    type4 = np.array(df[df.type == 4].iloc[:,g])
    
    # run 1-way between subjects ANOVA
    # Returns: The computed F statistic of the test; The associated p-value from the F distribution.
    result = f_oneway(type0, type1, type2, type3, type4)
    
    # append p-value
    stat_ANOVA.append(result[1])
        
    if g%1000 == 0:
        print(g)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000

# %%
# if the p value of the specific gene (between all subtypes) is less than 0.0001 then return the gene
# first two colunms are sample and type
stat_TF = [True, True]

for i in stat_ANOVA:
    if i <= 0.0001:
        stat_TF.append(True)
    else:
        stat_TF.append(False)

# %%
# stat_TF has the corresponding order with genes
# if stat_TF = True, get the column through .loc
df_ANOVA = df.loc[:,stat_TF]
df_ANOVA
# Out:
#      samples  type  1007_s_at   1053_at     117_at  1255_g_at   1294_at  \
# 0        834     0  12.498150  7.604868   6.880934   4.176175  7.224920
# 1        835     0  13.067436  7.998090   7.209076   4.826126  7.539381
# 2        836     0  13.068179  8.573674   8.647684   4.396581  7.813101
# 3        837     0  12.456040  9.098977   6.628784   4.154847  8.361843
# 4        838     0  12.699958  8.800721  11.556188   4.165891  7.923826
# ..       ...   ...        ...       ...        ...        ...       ...
# 125      959     3  12.658228  8.843270   7.672655   5.495477  8.603892
# 126      960     3  12.812823  8.510550   8.729699   3.967228  7.719089
# 127      961     3  12.706991  8.795721   7.772359   6.329383  8.550471
# 128      962     3  12.684593  8.293938   7.228186   6.049414  8.214729
# 129      963     3  12.397722  8.843524   8.825100   5.002072  8.547894
#
#       1431_at   1438_at   1487_at  ...   91920_at  AFFX-HSAC07/X00351_3_at  \
# ...

# %%
# Use variance to filter
stat_var = []

# loop through each genes
for g in range(2, df_ANOVA.shape[1]):
    stat_var.append(statistics.variance(df_ANOVA.iloc[:,g]))
    if g % 1000 == 0:
        print(g)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000

# %%
np.median(stat_var)
# Out:
# 0.5088812901520702

# %%
var_TF = [True, True]
for i in stat_var:
    if i >= 0.5:
        var_TF.append(True)
    else:
        var_TF.append(False)

# %%
df_var = df_ANOVA.loc[:,var_TF]
df_var
# Out:
#      samples  type  1007_s_at     117_at  1255_g_at   1438_at  1552256_a_at  \
# 0        834     0  12.498150   6.880934   4.176175  7.541986      8.386617
# 1        835     0  13.067436   7.209076   4.826126  8.317030      9.208559
# 2        836     0  13.068179   8.647684   4.396581  7.661874      9.344553
# 3        837     0  12.456040   6.628784   4.154847  7.663790      8.996408
# 4        838     0  12.699958  11.556188   4.165891  9.521956     10.040652
# ..       ...   ...        ...        ...        ...       ...           ...
# 125      959     3  12.658228   7.672655   5.495477  7.014209     10.233177
# 126      960     3  12.812823   8.729699   3.967228  7.981177      9.902292
# 127      961     3  12.706991   7.772359   6.329383  6.638493      9.638112
# 128      962     3  12.684593   7.228186   6.049414  7.225376     10.145374
# 129      963     3  12.397722   8.825100   5.002072  6.839369      9.731481
#
# ...

# %%
# Use Information Gain to filter

# x is columns for genes
# y is the cancer type
X = np.array(df_var.iloc[:,2:])
y = np.array(df_var.iloc[:,1])

IG = mutual_info_classif(X,y,n_neighbors = 5)
print("IG done")
# Out:
# IG done

# %%
# Select top 3000 feature based on importance from Information Gain
rank = rankdata(IG)
rank_TF = [True, True]
for i in rank:
    if i <= 3000:
        rank_TF.append(True)
    else:
        rank_TF.append(False)

df_ig = df_var.loc[:,rank_TF]
df_ig
# Out:
#      samples  type   1438_at  1552274_at  1552275_s_at  1552301_a_at  \
# 0        834     0  7.541986    6.522746      7.031419      7.160071
# 1        835     0  8.317030    7.805840      7.953560      6.529700
# 2        836     0  7.661874    7.702766      7.713712      8.191684
# 3        837     0  7.663790    7.073578      7.603237      5.758467
# 4        838     0  9.521956    7.916434      8.139826      7.042512
# ..       ...   ...       ...         ...           ...           ...
# 125      959     3  7.014209    7.350546      7.826477      6.133921
# 126      960     3  7.981177    8.527913      8.150819      6.679918
# 127      961     3  6.638493    7.797212      8.870719      6.233379
# 128      962     3  7.225376    8.126196      8.580536      5.912674
# 129      963     3  6.839369    7.350742      7.187392      6.266402
#
#      1552309_a_at  1552312_a_at  1552316_a_at  1552343_s_at  ...  53071_s_at  \
# ...

# %% [markdown]
# ## Wrapper Methods

# %%
#x is columns for genes (features)
#y is the cancer type
X_new = df_ig.iloc[:,2:]
y_new = df_ig.iloc[:,1]
model = LinearRegression()
rfe = RFE(model, n_features_to_select = 300)
print("rfe done")
#Use RFE to select the top 300 features 
fit = rfe.fit(X_new, y_new)
print('fit done')
# Out:
# rfe done
# fit done

# %%
RFE_results = []
for i in range(X_new.shape[1]):
    RFE_results.append(rfe.support_[i])

# %%
RFE_TF = [True, True]
for i in RFE_results:
    if i == True:
        RFE_TF.append(True)
    else:
        RFE_TF.append(False)

# %%
df_RFE = df_ig.loc[:,RFE_TF]

# %%
df_RFE
# Out:
#      samples  type  1552508_at  1552516_a_at  1552575_a_at  1552807_a_at  \
# 0        834     0    5.989892      8.660293      6.891804      7.924462
# 1        835     0    8.319513      9.980202      6.826210      7.493678
# 2        836     0    7.261455      8.212629      6.270775      8.045542
# 3        837     0    5.883377      6.236439      6.029005      8.071778
# 4        838     0    6.665956      8.035231      7.614323      7.692385
# ..       ...   ...         ...           ...           ...           ...
# 125      959     3    7.563709      5.266555      6.658161      8.404671
# 126      960     3   10.704805      6.485646      6.094978      9.212460
# 127      961     3    6.450710      5.612284      5.766023     10.130702
# 128      962     3    7.456670      5.587341      5.885478      8.975262
# 129      963     3    8.118853      5.633060      6.214792      9.423301
#
#      1553479_at  1553654_at  1554018_at  1554507_at  ...  242134_at  \
# ...

# %% [markdown]
# ## SMOTE

# %%
# Because we have multivariable unbalanced data, we need to use SMOTE to balance data type.
x_smote = df_RFE.iloc[:,2:]
y_smote = df_RFE.iloc[:,1]
oversample = SMOTE()
x_smote, y_smote = oversample.fit_resample(x_smote, y_smote)

# %%
subtype_counts_smote = count_plot(y_smote, "Five different subtype data counts")
subtype_counts_smote

# %%
x_smote
# Out:
#      1552508_at  1552516_a_at  1552575_a_at  1552807_a_at  1553479_at  \
# 0      5.989892      8.660293      6.891804      7.924462    6.895976
# 1      8.319513      9.980202      6.826210      7.493678    7.775287
# 2      7.261455      8.212629      6.270775      8.045542    8.177457
# 3      5.883377      6.236439      6.029005      8.071778    5.224647
# 4      6.665956      8.035231      7.614323      7.692385    7.442830
# ..          ...           ...           ...           ...         ...
# 225    6.075908      5.905048      6.747455      8.853288    8.155167
# 226    6.289365      6.627597      7.139963      7.722093    8.383120
# 227    6.619972      6.770995      8.068314      8.444597    9.003737
# 228    6.104033      5.499291      6.727333      8.499996    7.861872
# 229    6.283671      5.159577      6.167573      8.306796    8.572784
#
#      1553654_at  1554018_at  1554507_at  1554544_a_at  1554757_a_at  ...  \
# ...

# %%
# write out the data frame after SMOTE
df_smote = x_smote.copy()
df_smote.insert(0, "type", y_smote)

# %%
df_smote
# Out:
#      type  1552508_at  1552516_a_at  1552575_a_at  1552807_a_at  1553479_at  \
# 0       0    5.989892      8.660293      6.891804      7.924462    6.895976
# 1       0    8.319513      9.980202      6.826210      7.493678    7.775287
# 2       0    7.261455      8.212629      6.270775      8.045542    8.177457
# 3       0    5.883377      6.236439      6.029005      8.071778    5.224647
# 4       0    6.665956      8.035231      7.614323      7.692385    7.442830
# ..    ...         ...           ...           ...           ...         ...
# 225     4    6.075908      5.905048      6.747455      8.853288    8.155167
# 226     4    6.289365      6.627597      7.139963      7.722093    8.383120
# 227     4    6.619972      6.770995      8.068314      8.444597    9.003737
# 228     4    6.104033      5.499291      6.727333      8.499996    7.861872
# 229     4    6.283671      5.159577      6.167573      8.306796    8.572784
#
# ...

# %%
df_smote.to_csv("df_w_var.csv", index = False)
